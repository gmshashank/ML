# %%
# %matplotlib notebook

from fastai.imports import *
from sklearn.ensemble import RandomForestRegressor

# %%
x = np.linspace(-1,1)
x
# Out:
# array([-1.        , -0.95918367, -0.91836735, -0.87755102, -0.83673469,
#        -0.79591837, -0.75510204, -0.71428571, -0.67346939, -0.63265306,
#        -0.59183673, -0.55102041, -0.51020408, -0.46938776, -0.42857143,
#        -0.3877551 , -0.34693878, -0.30612245, -0.26530612, -0.2244898 ,
#        -0.18367347, -0.14285714, -0.10204082, -0.06122449, -0.02040816,
#         0.02040816,  0.06122449,  0.10204082,  0.14285714,  0.18367347,
#         0.2244898 ,  0.26530612,  0.30612245,  0.34693878,  0.3877551 ,
#         0.42857143,  0.46938776,  0.51020408,  0.55102041,  0.59183673,
#         0.63265306,  0.67346939,  0.71428571,  0.75510204,  0.79591837,
#         0.83673469,  0.87755102,  0.91836735,  0.95918367,  1.        ])

# %%
x.shape      #its a vector
# Out:
# (50,)

# %%
y = x + np.random.uniform(-0.2,0.2,x.shape)
y
# Out:
# array([-1.04855043, -0.92231947, -0.92585937, -0.69032739, -0.7120424 ,
#        -0.93590738, -0.94033954, -0.56816522, -0.72480392, -0.5437579 ,
#        -0.66283922, -0.42029075, -0.31472759, -0.35860369, -0.37052011,
#        -0.56458551, -0.4112109 , -0.45733072, -0.39862322, -0.04680887,
#        -0.20820161, -0.30702796, -0.08866755,  0.11205509, -0.03994961,
#         0.15086635, -0.0060358 ,  0.20335846, -0.05403113,  0.31666663,
#         0.15663043,  0.07889509,  0.1268264 ,  0.53482379,  0.20345264,
#         0.47821299,  0.54706534,  0.31720081,  0.67096859,  0.57519049,
#         0.57951259,  0.71613835,  0.89820896,  0.66983272,  0.80944005,
#         0.93207687,  0.82765289,  0.82231792,  1.15630285,  1.16184484])

# %%
plt.figure()
plt.scatter(x,y);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x_trn,x_val = x[:40],x[40:]
y_trn,y_val = y[:40],y[:40]

# %%
m = RandomForestRegressor().fit(x_trn,y_trn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-9670413f6e9f> in <module>
# ----> 1 m = RandomForestRegressor().fit(x_trn,y_trn)
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     302             )
#     303         X, y = self._validate_data(X, y, multi_output=True,
# --> 304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#     306             sample_weight = _check_sample_weight(sample_weight, X)
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
# ...

# %% [raw]
# None can be used as special indexer to introduce a new unit axis.
# It can be used to convert a vector into matrix

# %%
x[:,None].shape   #it's a matrix
# Out:
# (50, 1)

# %% [raw]
# OR  (Both are the same)

# %%
x[None].shape
# Out:
# (1, 50)

# %%
x[None,:].shape
# Out:
# (1, 50)

# %% [raw]
# Append a None column towards end of the existing matrix

# %%
x1 = x[...,None]

# %%
x_trn,x_val = x1[:40],x1[40:]
y_trn,y_val = y[:40],y[40:]

# %%
m = RandomForestRegressor().fit(x_trn,y_trn)

# %%
plt.figure()
plt.scatter(y_trn,m.predict(x_trn));
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.scatter(y_val,m.predict(x_val));
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [raw]
# here we have not transformed the y_val data

# %%
# plt.scatter(y_val,m.predict())
